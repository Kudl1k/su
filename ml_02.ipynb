# %% [markdown]
# # Machine Learning - Exercise 2
# The aim of the exercise is to get an overview of the basic capabilities of the Pandas, Matplotlib and Seaborn libraries for the Data analysis, Vizualization and Data Transformation
#
# **Jupyter lab**
#
# * Add code
# * Add text
# * Execute command
# * Shortcuts (a, b, dd, Ctrl+Enter, Shift+Enter, x, c, v)
#
# **Alternatives**
#
# * Google Colab ([Colaboratory](https://colab.research.google.com/))
# * Python scripts in VS Code
#
# "![meme01](https://github.com/lowoncuties/VSB-FEI-Machine-Learning-Exercises/blob/main/images/fml_01_meme_01.png?raw=true)

# %% [markdown]
# ## Import used packages

# %%
import pandas as pd # dataframes
import numpy as np # matrices and linear algebra
import matplotlib.pyplot as plt # plotting
import seaborn as sns # another matplotlib interface - styled and easier to use
import sklearn.preprocessing # library for data preprocessing

# %% [markdown]
# ## Load data into Pandas DataFrame

# %%
df_full = pd.read_csv('https://raw.githubusercontent.com/lowoncuties/VSB-FEI-Machine-Learning-Exercises/master/datasets/ml_02/global_house_purchase_dataset.csv', sep=',')
df_full
# Out:
#         property_id       country            city property_type  \
# 0                 1        France       Marseille     Farmhouse
# 1                 2  South Africa       Cape Town     Apartment
# 2                 3  South Africa    Johannesburg     Farmhouse
# 3                 4       Germany       Frankfurt     Farmhouse
# 4                 5  South Africa    Johannesburg     Townhouse
# ...             ...           ...             ...           ...
# 199995       199996       Germany          Berlin         Villa
# 199996       199997         China        Shenzhen     Townhouse
# 199997       199998         Japan           Kyoto         Villa
# 199998       199999  South Africa    Johannesburg     Apartment
# 199999       200000        Brazil  Rio de Janeiro     Apartment
#
#        furnishing_status  property_size_sqft    price  constructed_year  \
# 0         Semi-Furnished                 991   412935              1989
# 1         Semi-Furnished                1244   224538              1990
# 2         Semi-Furnished                4152   745104              2019
# 3         Semi-Furnished                3714  1110959              2008
# 4        Fully-Furnished                 531    99041              2007
# ...                  ...                 ...      ...               ...
# 199995   Fully-Furnished                 685   203328              1968
# 199996       Unfurnished                3818  1454627              1977
# 199997    Semi-Furnished                3603  1619147              1990
# 199998       Unfurnished                1706   306165              2010
# 199999    Semi-Furnished                3652   732698              1986
#
#         previous_owners  rooms  ...  customer_salary  loan_amount  \
# 0                     6      6  ...            10745       193949
# 1                     4      8  ...            16970       181465
# 2                     5      2  ...            21914       307953
# 3                     1      3  ...            17980       674720
# 4                     6      3  ...            17676        65833
# ...                 ...    ...  ...              ...          ...
# 199995                1      3  ...            78330       104050
# 199996                5      7  ...            25400      1175297
# 199997                2      4  ...            28220       743049
# 199998                0      4  ...            12240       150774
# 199999                0      1  ...            22644       548714
#
#         loan_tenure_years  monthly_expenses  down_payment  \
# 0                      15              6545        218986
# 1                      20              8605         43073
# 2                      30              2510        437151
# 3                      15              8805        436239
# 4                      25              8965         33208
# ...                   ...               ...           ...
# 199995                 15             17670         99278
# 199996                 20              2865        279330
# 199997                 30              5595        876098
# 199998                 15             16300        155391
# 199999                 30              5165        183984
#
#         emi_to_income_ratio  satisfaction_score  neighbourhood_rating  \
# 0                      0.16                   1                     5
# 1                      0.08                   9                     1
# 2                      0.09                   6                     8
# 3                      0.33                   2                     6
# 4                      0.03                   3                     3
# ...                     ...                 ...                   ...
# 199995                 0.01                   8                     4
# 199996                 0.34                   7                    10
# 199997                 0.17                   5                     3
# 199998                 0.11                   6                    10
# 199999                 0.15                   6                     4
#
#         connectivity_score  decision
# 0                        6         0
# 1                        2         0
# 2                        1         0
# 3                        6         0
# 4                        4         0
# ...                    ...       ...
# 199995                   5         1
# 199996                   9         1
# 199997                   9         0
# 199998                   6         0
# 199999                   9         0
#
# [200000 rows x 25 columns]

# %% [markdown]
# ## Show first 5 rows

# %%
df_full.head()
# Out:
#    property_id       country          city property_type furnishing_status  \
# 0            1        France     Marseille     Farmhouse    Semi-Furnished
# 1            2  South Africa     Cape Town     Apartment    Semi-Furnished
# 2            3  South Africa  Johannesburg     Farmhouse    Semi-Furnished
# 3            4       Germany     Frankfurt     Farmhouse    Semi-Furnished
# 4            5  South Africa  Johannesburg     Townhouse   Fully-Furnished
#
#    property_size_sqft    price  constructed_year  previous_owners  rooms  ...  \
# 0                 991   412935              1989                6      6  ...
# 1                1244   224538              1990                4      8  ...
# 2                4152   745104              2019                5      2  ...
# 3                3714  1110959              2008                1      3  ...
# 4                 531    99041              2007                6      3  ...
#
#    customer_salary  loan_amount  loan_tenure_years  monthly_expenses  \
# 0            10745       193949                 15              6545
# 1            16970       181465                 20              8605
# 2            21914       307953                 30              2510
# 3            17980       674720                 15              8805
# 4            17676        65833                 25              8965
#
#    down_payment  emi_to_income_ratio  satisfaction_score  \
# 0        218986                 0.16                   1
# 1         43073                 0.08                   9
# 2        437151                 0.09                   6
# 3        436239                 0.33                   2
# 4         33208                 0.03                   3
#
#    neighbourhood_rating  connectivity_score  decision
# 0                     5                   6         0
# 1                     1                   2         0
# 2                     8                   1         0
# 3                     6                   6         0
# 4                     3                   4         0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Show last 20 rows

# %%
df_full.tail(20)
# Out:
#         property_id       country            city property_type  \
# 199980       199981           USA     Los Angeles         Villa
# 199981       199982        Canada         Toronto     Apartment
# 199982       199983        Canada       Vancouver     Farmhouse
# 199983       199984         India          Mumbai     Farmhouse
# 199984       199985     Singapore       Singapore     Farmhouse
# 199985       199986       Germany       Frankfurt         Villa
# 199986       199987       Germany       Frankfurt     Apartment
# 199987       199988       Germany       Frankfurt         Villa
# 199988       199989        Canada        Montreal     Farmhouse
# 199989       199990        Canada        Montreal     Farmhouse
# 199990       199991           USA        New York     Townhouse
# 199991       199992     Singapore       Singapore     Apartment
# 199992       199993         Japan           Kyoto     Farmhouse
# 199993       199994     Australia       Melbourne     Townhouse
# 199994       199995         Japan           Osaka     Farmhouse
# 199995       199996       Germany          Berlin         Villa
# 199996       199997         China        Shenzhen     Townhouse
# 199997       199998         Japan           Kyoto         Villa
# 199998       199999  South Africa    Johannesburg     Apartment
# 199999       200000        Brazil  Rio de Janeiro     Apartment
#
#        furnishing_status  property_size_sqft    price  constructed_year  \
# 199980   Fully-Furnished                3772  1884903              2019
# 199981       Unfurnished                3678  1290582              1997
# 199982       Unfurnished                1892   661046              1980
# 199983       Unfurnished                3576   536351              1970
# 199984       Unfurnished                2454  1717199              1993
# 199985   Fully-Furnished                5235  1572148              2008
# 199986       Unfurnished                2897   873002              1981
# 199987   Fully-Furnished                3881  1166112              2020
# 199988    Semi-Furnished                3916  1367157              1965
# 199989   Fully-Furnished                2582   908676              1961
# 199990   Fully-Furnished                 758   378580              2010
# 199991    Semi-Furnished                2178  1525303              2010
# 199992   Fully-Furnished                5553  2497748              1965
# 199993    Semi-Furnished                3554  1141359              2008
# 199994   Fully-Furnished                5321  2396910              1963
# 199995   Fully-Furnished                 685   203328              1968
# 199996       Unfurnished                3818  1454627              1977
# 199997    Semi-Furnished                3603  1619147              1990
# 199998       Unfurnished                1706   306165              2010
# 199999    Semi-Furnished                3652   732698              1986
#
#         previous_owners  rooms  ...  customer_salary  loan_amount  \
# 199980                0      6  ...            69100      1460078
# 199981                0      1  ...            55265       716207
# 199982                1      3  ...            26310       525537
# 199983                6      1  ...            16496       368784
# 199984                3      7  ...            33515       736553
# 199985                4      4  ...            94315      1112063
# 199986                1      2  ...            80110       371143
# 199987                4      8  ...            82205       926023
# 199988                0      1  ...            82510       687006
# 199989                1      5  ...            84200       641479
# 199990                4      7  ...            18555       219850
# 199991                6      5  ...            12010      1167940
# 199992                0      4  ...            28865      1547889
# 199993                5      6  ...            96425       470809
# 199994                3      8  ...            17825      1056582
# 199995                1      3  ...            78330       104050
# 199996                5      7  ...            25400      1175297
# 199997                2      4  ...            28220       743049
# 199998                0      4  ...            12240       150774
# 199999                0      1  ...            22644       548714
#
#         loan_tenure_years  monthly_expenses  down_payment  \
# 199980                 30             12185        424825
# 199981                 10             14545        574375
# 199982                 10              4720        135509
# 199983                 30              1925        167567
# 199984                 25              8190        980646
# 199985                 15             16985        460085
# 199986                 10             16795        501859
# 199987                 10              5505        240089
# 199988                 15              8950        680151
# 199989                 10             13005        267197
# 199990                 30             10490        158730
# 199991                 30              6205        357363
# 199992                 20             15300        949859
# 199993                 10             17790        670550
# 199994                 20             11095       1340328
# 199995                 15             17670         99278
# 199996                 20              2865        279330
# 199997                 30              5595        876098
# 199998                 15             16300        155391
# 199999                 30              5165        183984
#
#         emi_to_income_ratio  satisfaction_score  neighbourhood_rating  \
# 199980                 0.13                   6                     2
# 199981                 0.15                   7                     1
# 199982                 0.23                   2                     3
# 199983                 0.14                   8                     7
# 199984                 0.15                   5                     8
# 199985                 0.10                   6                     9
# 199986                 0.05                   1                     1
# 199987                 0.13                   9                     3
# 199988                 0.07                   7                    10
# 199989                 0.09                   2                     6
# 199990                 0.07                   4                     3
# 199991                 0.61                   9                     3
# 199992                 0.40                   3                     9
# 199993                 0.06                   3                     3
# 199994                 0.44                   9                    10
# 199995                 0.01                   8                     4
# 199996                 0.34                   7                    10
# 199997                 0.17                   5                     3
# 199998                 0.11                   6                    10
# 199999                 0.15                   6                     4
#
#         connectivity_score  decision
# 199980                   7         0
# 199981                   6         0
# 199982                   1         0
# 199983                   6         1
# 199984                   9         0
# 199985                   8         0
# 199986                   3         0
# 199987                   9         1
# 199988                   5         0
# 199989                  10         0
# 199990                   3         0
# 199991                   9         0
# 199992                   6         0
# 199993                   9         0
# 199994                   2         0
# 199995                   5         1
# 199996                   9         1
# 199997                   9         0
# 199998                   6         0
# 199999                   9         0
#
# [20 rows x 25 columns]

# %% [markdown]
# ## If we want to know if there are any missing values, the isna() function may render useful

# %%
df_full.isna().sum()
# Out:
# property_id                0
# country                    0
# city                       0
# property_type              0
# furnishing_status          0
# property_size_sqft         0
# price                      0
# constructed_year           0
# previous_owners            0
# rooms                      0
# bathrooms                  0
# garage                     0
# garden                     0
# crime_cases_reported       0
# legal_cases_on_property    0
# customer_salary            0
# loan_amount                0
# loan_tenure_years          0
# monthly_expenses           0
# down_payment               0
# emi_to_income_ratio        0
# satisfaction_score         0
# neighbourhood_rating       0
# connectivity_score         0
# decision                   0
# dtype: int64

# %% [markdown]
# ## We can show summary of common statistical characteristic of the data using the describe() function

# %%
df_full.describe()
# Out:
#          property_id  property_size_sqft         price  constructed_year  \
# count  200000.000000       200000.000000  2.000000e+05     200000.000000
# mean   100000.500000         3195.633460  1.215365e+06       1991.487770
# std     57735.171256         1613.322287  8.236633e+05         18.494064
# min         1.000000          400.000000  5.628800e+04       1960.000000
# 25%     50000.750000         1802.000000  5.659895e+05       1975.000000
# 50%    100000.500000         3190.000000  1.023429e+06       1991.000000
# 75%    150000.250000         4589.000000  1.725556e+06       2008.000000
# max    200000.000000         6000.000000  4.202732e+06       2023.000000
#
#        previous_owners          rooms      bathrooms         garage  \
# count    200000.000000  200000.000000  200000.000000  200000.000000
# mean          3.001370       4.513855       2.760030       0.499350
# std           2.002198       2.295669       1.840959       0.500001
# min           0.000000       1.000000       1.000000       0.000000
# 25%           1.000000       3.000000       1.000000       0.000000
# 50%           3.000000       5.000000       2.000000       0.000000
# 75%           5.000000       7.000000       4.000000       1.000000
# max           6.000000       8.000000       8.000000       1.000000
#
#               garden  crime_cases_reported  ...  customer_salary  \
# count  200000.000000         200000.000000  ...    200000.000000
# mean        0.500215              1.229065  ...     46528.625830
# std         0.500001              1.185336  ...     27997.353766
# min         0.000000              0.000000  ...      2000.000000
# 25%         0.000000              0.000000  ...     21450.000000
# 50%         1.000000              1.000000  ...     41465.000000
# 75%         1.000000              2.000000  ...     70805.000000
# max         1.000000             10.000000  ...    100000.000000
#
#         loan_amount  loan_tenure_years  monthly_expenses  down_payment  \
# count  2.000000e+05      200000.000000     200000.000000  2.000000e+05
# mean   7.597583e+05          19.986375      10559.693105  4.556068e+05
# std    5.489401e+05           7.081080       5427.241879  3.629865e+05
# min    2.350400e+04          10.000000        500.000000  8.966000e+03
# 25%    3.372802e+05          15.000000       5770.000000  1.849592e+05
# 50%    6.269325e+05          20.000000      10520.000000  3.561700e+05
# 75%    1.058416e+06          25.000000      15260.000000  6.257352e+05
# max    3.520150e+06          30.000000      20000.000000  2.492723e+06
#
#        emi_to_income_ratio  satisfaction_score  neighbourhood_rating  \
# count        200000.000000       200000.000000         200000.000000
# mean              0.195387            5.498650              5.505240
# std               0.219689            2.875361              2.870945
# min               0.000000            1.000000              1.000000
# 25%               0.070000            3.000000              3.000000
# 50%               0.130000            5.000000              5.000000
# 75%               0.240000            8.000000              8.000000
# max               3.460000           10.000000             10.000000
#
#        connectivity_score       decision
# count       200000.000000  200000.000000
# mean             5.495615       0.230340
# std              2.870206       0.421052
# min              1.000000       0.000000
# 25%              3.000000       0.000000
# 50%              5.000000       0.000000
# 75%              8.000000       0.000000
# max             10.000000       1.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# ## 💡 Dataframe has several useful properties
#     - shape
#     - dtypes
#     - columns
#     - index

# %% [markdown]
# ### Row and column count

# %%
df_full.shape
# Out:
# (200000, 25)

# %% [markdown]
# ### Datatypes of columns

# %%
df_full.dtypes
# Out:
# property_id                  int64
# country                     object
# city                        object
# property_type               object
# furnishing_status           object
# property_size_sqft           int64
# price                        int64
# constructed_year             int64
# previous_owners              int64
# rooms                        int64
# bathrooms                    int64
# garage                       int64
# garden                       int64
# crime_cases_reported         int64
# legal_cases_on_property      int64
# customer_salary              int64
# loan_amount                  int64
# loan_tenure_years            int64
# monthly_expenses             int64
# down_payment                 int64
# emi_to_income_ratio        float64
# satisfaction_score           int64
# neighbourhood_rating         int64
# connectivity_score           int64
# decision                     int64
# dtype: object

# %% [markdown]
# ### Column names

# %%
df_full.columns
# Out:
# Index(['property_id', 'country', 'city', 'property_type', 'furnishing_status',
#        'property_size_sqft', 'price', 'constructed_year', 'previous_owners',
#        'rooms', 'bathrooms', 'garage', 'garden', 'crime_cases_reported',
#        'legal_cases_on_property', 'customer_salary', 'loan_amount',
#        'loan_tenure_years', 'monthly_expenses', 'down_payment',
#        'emi_to_income_ratio', 'satisfaction_score', 'neighbourhood_rating',
#        'connectivity_score', 'decision'],
#       dtype='object')

# %% [markdown]
# ### Row index values

# %%
df_full.index
# Out:
# RangeIndex(start=0, stop=200000, step=1)

# %% [markdown]
# ## We may want to work with just one column not the whole dataframe
# - We will select only the price columns and save it to another variable

# %%
df_price = df_full['price']
df_price
# Out:
# 0          412935
# 1          224538
# 2          745104
# 3         1110959
# 4           99041
#            ...
# 199995     203328
# 199996    1454627
# 199997    1619147
# 199998     306165
# 199999     732698
# Name: price, Length: 200000, dtype: int64

# %% [markdown]
# ## Columns are called Pandas Series - it shares a common API with Pandas DataFrame
# - 💡 Pandas is numpy-backed so we can use Series as standard numpy arrays without any issues using the .values property

# %%
df_price.values
# Out:
# array([ 412935,  224538,  745104, ..., 1619147,  306165,  732698],
#       shape=(200000,))

# %% [markdown]
# ## Find maximum price using Numpy and Pandas

# %%
df_price.max()
# Out:
# np.int64(4202732)

# %%
df_price.min()
# Out:
# np.int64(56288)

# %% [markdown]
# ## Data filtering using Pandas DataFrame
# - There are several ways of filtering the data (similar logic to .Where() in C# or WHERE in SQL)
# - 💡 We usually work with two indexers - .loc[] and .iloc[]
#
# ### The .iloc[] indexer works with positional indexes - very close to the way of working with the raw arrays
# ### The .loc[] indexer works with column names and logical expressions

# %% [markdown]
# ### Select all rows and 3rd column of dataframe

# %%
df_full.iloc[:, 2]
# Out:
# 0              Marseille
# 1              Cape Town
# 2           Johannesburg
# 3              Frankfurt
# 4           Johannesburg
#                ...
# 199995            Berlin
# 199996          Shenzhen
# 199997             Kyoto
# 199998      Johannesburg
# 199999    Rio de Janeiro
# Name: city, Length: 200000, dtype: object

# %% [markdown]
# ### Select all rows and LAST column of dataframe

# %%
df_full.iloc[:, -1]
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 199995    1
# 199996    1
# 199997    0
# 199998    0
# 199999    0
# Name: decision, Length: 200000, dtype: int64

# %% [markdown]
# ### Select 4th to 10th row and all columns

# %%
df_full.iloc[:, 3:9]
# Out:
#        property_type furnishing_status  property_size_sqft    price  \
# 0          Farmhouse    Semi-Furnished                 991   412935
# 1          Apartment    Semi-Furnished                1244   224538
# 2          Farmhouse    Semi-Furnished                4152   745104
# 3          Farmhouse    Semi-Furnished                3714  1110959
# 4          Townhouse   Fully-Furnished                 531    99041
# ...              ...               ...                 ...      ...
# 199995         Villa   Fully-Furnished                 685   203328
# 199996     Townhouse       Unfurnished                3818  1454627
# 199997         Villa    Semi-Furnished                3603  1619147
# 199998     Apartment       Unfurnished                1706   306165
# 199999     Apartment    Semi-Furnished                3652   732698
#
#         constructed_year  previous_owners
# 0                   1989                6
# 1                   1990                4
# 2                   2019                5
# 3                   2008                1
# 4                   2007                6
# ...                  ...              ...
# 199995              1968                1
# 199996              1977                5
# 199997              1990                2
# 199998              2010                0
# 199999              1986                0
#
# [200000 rows x 6 columns]

# %% [markdown]
# ### Select 2nd to 13th row and 3rd column

# %%
df_full.iloc[1:12, 2]
# Out:
# 1          Cape Town
# 2       Johannesburg
# 3          Frankfurt
# 4       Johannesburg
# 5           Montreal
# 6     Rio de Janeiro
# 7          São Paulo
# 8              Dubai
# 9          Melbourne
# 10    Rio de Janeiro
# 11    Rio de Janeiro
# Name: city, dtype: object

# %% [markdown]
# ## Select only a subset of columns to a new dataframe
# > ['property_id', 'country','city','property_type','property_size_sqft','price','constructed_year','rooms','garden','crime_cases_reported','loan_amount','monthly_expenses']

# %%
df_full.loc[:, ['property_id', 'country','city','property_type','property_size_sqft','price','constructed_year','rooms','garden','crime_cases_reported','loan_amount','monthly_expenses']]
# Out:
#         property_id       country            city property_type  \
# 0                 1        France       Marseille     Farmhouse
# 1                 2  South Africa       Cape Town     Apartment
# 2                 3  South Africa    Johannesburg     Farmhouse
# 3                 4       Germany       Frankfurt     Farmhouse
# 4                 5  South Africa    Johannesburg     Townhouse
# ...             ...           ...             ...           ...
# 199995       199996       Germany          Berlin         Villa
# 199996       199997         China        Shenzhen     Townhouse
# 199997       199998         Japan           Kyoto         Villa
# 199998       199999  South Africa    Johannesburg     Apartment
# 199999       200000        Brazil  Rio de Janeiro     Apartment
#
#         property_size_sqft    price  constructed_year  rooms  garden  \
# 0                      991   412935              1989      6       1
# 1                     1244   224538              1990      8       1
# 2                     4152   745104              2019      2       1
# 3                     3714  1110959              2008      3       1
# 4                      531    99041              2007      3       1
# ...                    ...      ...               ...    ...     ...
# 199995                 685   203328              1968      3       0
# 199996                3818  1454627              1977      7       1
# 199997                3603  1619147              1990      4       1
# 199998                1706   306165              2010      4       0
# 199999                3652   732698              1986      1       0
#
#         crime_cases_reported  loan_amount  monthly_expenses
# 0                          1       193949              6545
# 1                          1       181465              8605
# 2                          0       307953              2510
# 3                          0       674720              8805
# 4                          3        65833              8965
# ...                      ...          ...               ...
# 199995                     1       104050             17670
# 199996                     1      1175297              2865
# 199997                     1       743049              5595
# 199998                     0       150774             16300
# 199999                     3       548714              5165
#
# [200000 rows x 12 columns]

# %% [markdown]
# ### Select only houses built in year 2000 or later
# * constructed_year

# %%
df_full.loc[df_full['constructed_year'] >= 2000]
# Out:
#         property_id       country            city property_type  \
# 2                 3  South Africa    Johannesburg     Farmhouse
# 3                 4       Germany       Frankfurt     Farmhouse
# 4                 5  South Africa    Johannesburg     Townhouse
# 7                 8        Brazil       São Paulo     Townhouse
# 10               11        Brazil  Rio de Janeiro     Apartment
# ...             ...           ...             ...           ...
# 199987       199988       Germany       Frankfurt         Villa
# 199990       199991           USA        New York     Townhouse
# 199991       199992     Singapore       Singapore     Apartment
# 199993       199994     Australia       Melbourne     Townhouse
# 199998       199999  South Africa    Johannesburg     Apartment
#
#        furnishing_status  property_size_sqft    price  constructed_year  \
# 2         Semi-Furnished                4152   745104              2019
# 3         Semi-Furnished                3714  1110959              2008
# 4        Fully-Furnished                 531    99041              2007
# 7         Semi-Furnished                4048   807236              2020
# 10       Fully-Furnished                5812  1166185              2017
# ...                  ...                 ...      ...               ...
# 199987   Fully-Furnished                3881  1166112              2020
# 199990   Fully-Furnished                 758   378580              2010
# 199991    Semi-Furnished                2178  1525303              2010
# 199993    Semi-Furnished                3554  1141359              2008
# 199998       Unfurnished                1706   306165              2010
#
#         previous_owners  rooms  ...  customer_salary  loan_amount  \
# 2                     5      2  ...            21914       307953
# 3                     1      3  ...            17980       674720
# 4                     6      3  ...            17676        65833
# 7                     4      6  ...            29832       503385
# 10                    4      8  ...            22342       918388
# ...                 ...    ...  ...              ...          ...
# 199987                4      8  ...            82205       926023
# 199990                4      7  ...            18555       219850
# 199991                6      5  ...            12010      1167940
# 199993                5      6  ...            96425       470809
# 199998                0      4  ...            12240       150774
#
#         loan_tenure_years  monthly_expenses  down_payment  \
# 2                      30              2510        437151
# 3                      15              8805        436239
# 4                      25              8965         33208
# 7                      20              7200        303851
# 10                     25              6895        247797
# ...                   ...               ...           ...
# 199987                 10              5505        240089
# 199990                 30             10490        158730
# 199991                 30              6205        357363
# 199993                 10             17790        670550
# 199998                 15             16300        155391
#
#         emi_to_income_ratio  satisfaction_score  neighbourhood_rating  \
# 2                      0.09                   6                     8
# 3                      0.33                   2                     6
# 4                      0.03                   3                     3
# 7                      0.13                   1                     5
# 10                     0.28                   8                     7
# ...                     ...                 ...                   ...
# 199987                 0.13                   9                     3
# 199990                 0.07                   4                     3
# 199991                 0.61                   9                     3
# 199993                 0.06                   3                     3
# 199998                 0.11                   6                    10
#
#         connectivity_score  decision
# 2                        1         0
# 3                        6         0
# 4                        4         0
# 7                        8         0
# 10                       6         1
# ...                    ...       ...
# 199987                   9         1
# 199990                   3         0
# 199991                   9         0
# 199993                   9         0
# 199998                   6         0
#
# [74995 rows x 25 columns]

# %% [markdown]
# ### Select only houses that are not Farmhouse (try != and ~ operators)
# * property_type

# %%
df_full.loc[df_full['property_type'] != 'Farmhouse']
# Out:
#         property_id       country            city property_type  \
# 1                 2  South Africa       Cape Town     Apartment
# 4                 5  South Africa    Johannesburg     Townhouse
# 5                 6        Canada        Montreal         Villa
# 6                 7        Brazil  Rio de Janeiro        Studio
# 7                 8        Brazil       São Paulo     Townhouse
# ...             ...           ...             ...           ...
# 199995       199996       Germany          Berlin         Villa
# 199996       199997         China        Shenzhen     Townhouse
# 199997       199998         Japan           Kyoto         Villa
# 199998       199999  South Africa    Johannesburg     Apartment
# 199999       200000        Brazil  Rio de Janeiro     Apartment
#
#        furnishing_status  property_size_sqft    price  constructed_year  \
# 1         Semi-Furnished                1244   224538              1990
# 4        Fully-Furnished                 531    99041              2007
# 5         Semi-Furnished                3169  1107368              1985
# 6            Unfurnished                1986   398439              1976
# 7         Semi-Furnished                4048   807236              2020
# ...                  ...                 ...      ...               ...
# 199995   Fully-Furnished                 685   203328              1968
# 199996       Unfurnished                3818  1454627              1977
# 199997    Semi-Furnished                3603  1619147              1990
# 199998       Unfurnished                1706   306165              2010
# 199999    Semi-Furnished                3652   732698              1986
#
#         previous_owners  rooms  ...  customer_salary  loan_amount  \
# 1                     4      8  ...            16970       181465
# 4                     6      3  ...            17676        65833
# 5                     0      5  ...            95520       793316
# 6                     1      2  ...            11426       268167
# 7                     4      6  ...            29832       503385
# ...                 ...    ...  ...              ...          ...
# 199995                1      3  ...            78330       104050
# 199996                5      7  ...            25400      1175297
# 199997                2      4  ...            28220       743049
# 199998                0      4  ...            12240       150774
# 199999                0      1  ...            22644       548714
#
#         loan_tenure_years  monthly_expenses  down_payment  \
# 1                      20              8605         43073
# 4                      25              8965         33208
# 5                      30             10615        314052
# 6                      25             14440        130272
# 7                      20              7200        303851
# ...                   ...               ...           ...
# 199995                 15             17670         99278
# 199996                 20              2865        279330
# 199997                 30              5595        876098
# 199998                 15             16300        155391
# 199999                 30              5165        183984
#
#         emi_to_income_ratio  satisfaction_score  neighbourhood_rating  \
# 1                      0.08                   9                     1
# 4                      0.03                   3                     3
# 5                      0.05                  10                     8
# 6                      0.16                   9                    10
# 7                      0.13                   1                     5
# ...                     ...                 ...                   ...
# 199995                 0.01                   8                     4
# 199996                 0.34                   7                    10
# 199997                 0.17                   5                     3
# 199998                 0.11                   6                    10
# 199999                 0.15                   6                     4
#
#         connectivity_score  decision
# 1                        2         0
# 4                        4         0
# 5                        2         1
# 6                       10         1
# 7                        8         0
# ...                    ...       ...
# 199995                   5         1
# 199996                   9         1
# 199997                   9         0
# 199998                   6         0
# 199999                   9         0
#
# [166482 rows x 25 columns]

# %% [markdown]
# ### Select houses cheaper than 200k USD and have atleast 6 rooms
# * price, rooms

# %%
df_full.loc[(df_full['price'] < 200000) & (df_full['rooms'] >= 6)]
# Out:
#         property_id       country            city      property_type  \
# 246             247       Germany          Berlin             Studio
# 256             257        Canada        Montreal          Farmhouse
# 401             402         China         Beijing              Villa
# 436             437        Brazil  Rio de Janeiro          Apartment
# 511             512  South Africa       Cape Town          Farmhouse
# ...             ...           ...             ...                ...
# 199768       199769     Australia       Melbourne  Independent House
# 199803       199804  South Africa    Johannesburg          Townhouse
# 199813       199814        Brazil       São Paulo          Apartment
# 199816       199817        Canada       Vancouver             Studio
# 199928       199929  South Africa       Cape Town          Apartment
#
#        furnishing_status  property_size_sqft   price  constructed_year  \
# 246      Fully-Furnished                 479  141697              2002
# 256          Unfurnished                 407  138317              1979
# 401       Semi-Furnished                 530  199708              1999
# 436          Unfurnished                 838  170744              2004
# 511          Unfurnished                1069  190989              1997
# ...                  ...                 ...     ...               ...
# 199768       Unfurnished                 556  181165              2006
# 199803   Fully-Furnished                 509   92722              2015
# 199813   Fully-Furnished                 871  172911              2019
# 199816   Fully-Furnished                 530  181996              1960
# 199928   Fully-Furnished                 402   75062              1997
#
#         previous_owners  rooms  ...  customer_salary  loan_amount  \
# 246                   6      8  ...            39210        87966
# 256                   6      8  ...            51885        99371
# 401                   1      6  ...            99920       154371
# 436                   6      7  ...            35794       112843
# 511                   0      7  ...            10914       122438
# ...                 ...    ...  ...              ...          ...
# 199768                1      6  ...            34195       138196
# 199803                6      8  ...            16806        70418
# 199813                0      6  ...            18286       130700
# 199816                5      7  ...            41615        76102
# 199928                0      8  ...            16946        45652
#
#         loan_tenure_years  monthly_expenses  down_payment  \
# 246                    20             18430         53731
# 256                    10             15030         38946
# 401                    20              8765         45337
# 436                    30             16790         57901
# 511                    10             14310         68551
# ...                   ...               ...           ...
# 199768                 20              9395         42969
# 199803                 10              8320         22304
# 199813                 30             13850         42211
# 199816                 20              8110        105894
# 199928                 15              9995         29410
#
#         emi_to_income_ratio  satisfaction_score  neighbourhood_rating  \
# 246                    0.02                   6                    10
# 256                    0.02                   2                     1
# 401                    0.01                   9                     2
# 436                    0.02                   2                     8
# 511                    0.13                   2                    10
# ...                     ...                 ...                   ...
# 199768                 0.03                   9                     7
# 199803                 0.05                   8                     7
# 199813                 0.05                   5                     3
# 199816                 0.01                   2                     4
# 199928                 0.02                   4                     9
#
#         connectivity_score  decision
# 246                      1         0
# 256                      8         0
# 401                      7         0
# 436                      9         0
# 511                      6         0
# ...                    ...       ...
# 199768                   1         0
# 199803                   7         1
# 199813                   3         0
# 199816                   9         0
# 199928                   8         0
#
# [3386 rows x 25 columns]

# %% [markdown]
# ### Select houses that are cheaper than 150K and are built after 1990 or have monthly expenses under 10K and are in France
# * price, constructed_year, monthly_expenses, country

# %%
df_full.loc[(df_full['price'] <= 150000) & (df_full['constructed_year'] >= 1990) | ((df_full['monthly_expenses'] <= 10000) & (df_full['country'] == 'France'))]
# Out:
#         property_id       country          city      property_type  \
# 0                 1        France     Marseille          Farmhouse
# 4                 5  South Africa  Johannesburg          Townhouse
# 64               65        France          Lyon          Farmhouse
# 85               86        France         Paris              Villa
# 97               98        France          Lyon              Villa
# ...             ...           ...           ...                ...
# 199928       199929  South Africa     Cape Town          Apartment
# 199930       199931        France         Paris          Townhouse
# 199951       199952        France          Lyon  Independent House
# 199957       199958        France     Marseille  Independent House
# 199962       199963        France         Paris             Studio
#
#        furnishing_status  property_size_sqft    price  constructed_year  \
# 0         Semi-Furnished                 991   412935              1989
# 4        Fully-Furnished                 531    99041              2007
# 64       Fully-Furnished                4658  1959099              2010
# 85        Semi-Furnished                1082   458248              1979
# 97           Unfurnished                 582   246076              1980
# ...                  ...                 ...      ...               ...
# 199928   Fully-Furnished                 402    75062              1997
# 199930   Fully-Furnished                4035  1694448              2004
# 199951   Fully-Furnished                4499  1892672              1990
# 199957       Unfurnished                 769   324317              1988
# 199962       Unfurnished                2580  1086529              2011
#
#         previous_owners  rooms  ...  customer_salary  loan_amount  \
# 0                     6      6  ...            10745       193949
# 4                     6      3  ...            17676        65833
# 64                    6      8  ...            11735      1271792
# 85                    3      8  ...            29220       335969
# 97                    6      7  ...            77990       150669
# ...                 ...    ...  ...              ...          ...
# 199928                0      8  ...            16946        45652
# 199930                5      2  ...            63600      1315189
# 199951                1      6  ...            22800       964556
# 199957                0      3  ...            62845       134469
# 199962                0      3  ...            85405       479789
#
#         loan_tenure_years  monthly_expenses  down_payment  \
# 0                      15              6545        218986
# 4                      25              8965         33208
# 64                     25              3995        687307
# 85                     15              7955        122279
# 97                     20              7135         95407
# ...                   ...               ...           ...
# 199928                 15              9995         29410
# 199930                 20              3295        379259
# 199951                 25              2855        928116
# 199957                 10              8720        189848
# 199962                 25              3095        606740
#
#         emi_to_income_ratio  satisfaction_score  neighbourhood_rating  \
# 0                      0.16                   1                     5
# 4                      0.03                   3                     3
# 64                     0.73                   2                     6
# 85                     0.10                   9                     9
# 97                     0.01                   6                    10
# ...                     ...                 ...                   ...
# 199928                 0.02                   4                     9
# 199930                 0.15                   5                     6
# 199951                 0.29                   4                     5
# 199957                 0.02                   7                     7
# 199962                 0.04                   9                     7
#
#         connectivity_score  decision
# 0                        6         0
# 4                        4         0
# 64                       6         0
# 85                       6         1
# 97                       6         0
# ...                    ...       ...
# 199928                   8         0
# 199930                  10         0
# 199951                   9         0
# 199957                   5         1
# 199962                   8         1
#
# [9005 rows x 25 columns]

# %% [markdown]
# # We can add new columns to the DataFrame as well
#
# ![meme02](https://github.com/lowoncuties/VSB-FEI-Machine-Learning-Exercises/blob/main/images/fml_01_meme_02.png?raw=true)

# %% [markdown]
# ### Add a new column named price_per_sqft_feet
# * price, property_size_sqft

# %%
df_full['price_per_sqft_feet'] = df_full['price'] / df_full['property_size_sqft']

# %% [markdown]
# ## Pandas enables us to use aggregation functions for the data using the .groupby() function

# %% [markdown]
# ### Compute counts for all the property types (groupby / value_counts)
# * property_type

# %%
df_full.groupby('property_type').value_counts()
# Out:
# property_type  property_id  country       city            furnishing_status  property_size_sqft  price    constructed_year  previous_owners  rooms  bathrooms  garage  garden  crime_cases_reported  legal_cases_on_property  customer_salary  loan_amount  loan_tenure_years  monthly_expenses  down_payment  emi_to_income_ratio  satisfaction_score  neighbourhood_rating  connectivity_score  decision  price_per_sqft_feet
# Apartment      2            South Africa  Cape Town       Semi-Furnished     1244                224538   1990              4                8      8          1       1       1                     1                        16970            181465       20                 8605              43073         0.08                 9                   1                     2                   0         180.496785             1
#                10           Australia     Melbourne       Unfurnished        4648                1483250  1966              2                5      2          0       1       0                     1                        67350            1093290      10                 16360             389960        0.18                 1                   4                     7                   0         319.115749             1
#                11           Brazil        Rio de Janeiro  Fully-Furnished    5812                1166185  2017              4                8      3          0       1       1                     0                        22342            918388       25                 6895              247797        0.28                 8                   7                     6                   1         200.651239             1
#                34           Australia     Melbourne       Semi-Furnished     2843                910130   1977              5                7      4          1       0       1                     0                        29505            380772       15                 12530             529358        0.11                 6                   10                    6                   0         320.130144             1
#                35           Canada        Montreal        Semi-Furnished     3094                1078050  1994              6                1      1          1       1       1                     0                        62025            603655       10                 8270              474395        0.11                 4                   10                    8                   0         348.432450             1
#                                                                                                                                                                                                                                                                                                                                                                                                                                   ..
# Villa          199981       USA           Los Angeles     Fully-Furnished    3772                1884903  2019              0                6      5          0       1       1                     0                        69100            1460078      30                 12185             424825        0.13                 6                   2                     7                   0         499.709173             1
#                199986       Germany       Frankfurt       Fully-Furnished    5235                1572148  2008              4                4      4          1       1       0                     0                        94315            1112063      15                 16985             460085        0.10                 6                   9                     8                   0         300.314804             1
#                199988       Germany       Frankfurt       Fully-Furnished    3881                1166112  2020              4                8      2          0       1       0                     0                        82205            926023       10                 5505              240089        0.13                 9                   3                     9                   1         300.466890             1
#                199996       Germany       Berlin          Fully-Furnished    685                 203328   1968              1                3      2          0       0       1                     0                        78330            104050       15                 17670             99278         0.01                 8                   4                     5                   1         296.829197             1
#                199998       Japan         Kyoto           Semi-Furnished     3603                1619147  1990              2                4      4          1       1       1                     0                        28220            743049       30                 5595              876098        0.17                 5                   3                     9                   0         449.388565             1
# Name: count, Length: 200000, dtype: int64

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Don't switch to scientific notation for plots

# %%
plt.rcParams['axes.formatter.useoffset'] = False   # remove the +1e6 offset text
plt.rcParams['axes.formatter.limits'] = (-100, 100)  # never switch to sci notation

# %% [markdown]
# ## Plots and how not to get lost among them
# Here’s a guide to help you decide which plot to choose for different situations

# %% [markdown]
# ### Histogram
# - **Purpose**: Displays the distribution of a single continuous variable by dividing the data into bins and showing how many values fall within each bin.
# - **Use it when**: You want to understand the distribution or shape of a dataset, identify multiple peaks (occurrences throughout the time, etc)
# - **Example**: Understanding how exam scores are distributed in a class.
# - **In-depth explanation** [Histogram](https://labxchange.org/library/items/lb:LabXchange:10d3270e:html:1)
#
#     ![Histogram explained](https://github.com/lowoncuties/VSB-FEI-Fundamentals-of-Machine-Learning-Exercises/blob/master/images/histogram_explained.png?raw=true)
#
# ### Boxplot
# - **Purpose**: Visualizes the summary statistics (e.g., median, quartiles) of a continuous variable, highlighting the spread of the data and potential outliers.
# - **Use it when**: You need to compare distributions across categories or identify outliers and the overall spread of the data.
# - **Example**: Comparing income distributions across different job titles.
# - **In-depth explanation** [Boxplot](https://www.simplypsychology.org/boxplots.html)
#
#     ![Boxplot explained](https://github.com/lowoncuties/VSB-FEI-Fundamentals-of-Machine-Learning-Exercises/blob/master/images/boxplot_explained.png?raw=true)
#
# ### Barplot
# - **Purpose**: Displays categorical data with bars representing the frequency or value of each category.
# - **Use it when**: You want to compare the size of different categories.
# - **Example**: Showing the number of students in each grade category (A, B, C).
# - **In-depth explanation** [Barplot](https://www.labxchange.org/library/items/lb:LabXchange:e034541a:html:1)
#
#   ![Barplot explained](https://github.com/lowoncuties/VSB-FEI-Fundamentals-of-Machine-Learning-Exercises/blob/master/images/barplot_explained.png?raw=true)
# ### Scatterplot
# - **Purpose**: Shows the relationship between two continuous variables, with each point representing an observation.
# - **Use it when**: You want to explore potential correlations or patterns between two variables.
# - **Example**: Exploring the relationship between hours studied and exam scores.
# - **In-depth explanation** [Scatterplot](https://www.atlassian.com/data/charts/what-is-a-scatter-plot)
#
#     ![Scatterplot explained](https://github.com/lowoncuties/VSB-FEI-Fundamentals-of-Machine-Learning-Exercises/blob/master/images/scatterplot_explained.png?raw=true)
#
# ### Line Plot
# - **Purpose**: Connects data points with a line to show trends over time or other ordered variables.
# - **Use it when**: You want to track changes or trends, especially over time.
# - **Example**: Visualizing the monthly sales of a product over a year.
# - **In-depth explanation** [Line plot/graph](https://www.atlassian.com/data/charts/line-chart-complete-guide)
#
#     ![Line plot/graph explained](https://github.com/lowoncuties/VSB-FEI-Fundamentals-of-Machine-Learning-Exercises/blob/master/images/lineplot_explained.png?raw=true)

# %% [markdown]
# ## Vizualize house prices in form of histogram
# - What does it tell us about the prices?

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_full['price'], bins=50)
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Modify bins
# - Perhaps we want to visualize the histogram with more dense or coarse bins
# - *bins* attribute

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_full['price'], bins=250)
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 🔎 What can we say about prices based on the quantiles?
# ### Use function *axvline* from Matplotlib to draw vertical lines at the quartile positions

# %%
#axvline
plt.figure(figsize=(10, 6))
sns.histplot(df_full['price'], bins=250)
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.axvline(df_full['price'].mean(), color='red', linestyle='dashed', linewidth=1)
plt.axvline(df_full['price'].median(), color='yellow', linestyle='dashed', linewidth=1)
plt.legend({'Mean':df_full['price'].mean(),'Median':df_full['price'].median()})
plt.show()

# %% [markdown]
# ## 💡 *col* attribute to automatically plot every histogram on its own canvas

# %% [markdown]
# # 📊 Another very useful tecnique for the numerical features distributions are boxplots
# - 🔎 Did you see any of these before?
#
# - 🔎 How should we read boxplots?
#     - **Quartiles**
#     - **Median**
#     - Box size
#     - **Outliers and IQR**
#     - Min/max - with or without outliers

# %% [markdown]
# ### Plot only the *price* using boxplot

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_full['price'])
plt.title('Boxplot of House Prices')
plt.xlabel('Price')
plt.show()

# %% [markdown]
# ## Let's take a look at the *price* for different *property_type* values
# - 🔎 What can we say about the prices?

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_full['property_type'], y=df_full['price'])
plt.title('Boxplot of House Prices by Property Type')
plt.xlabel('Property Type')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## We can do the same for *property_size_sqft*

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_full['property_type'], y=df_full['property_size_sqft'])
plt.title('Boxplot of Property Sizes by Property Type')
plt.xlabel('Property Type')
plt.ylabel('Property Size (sqft)')
plt.show()

# %% [markdown]
# ## Let's take a look at the *rooms* for different *property_type* values
# - 🔎 What can we say about that ?

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_full['property_type'], y=df_full['rooms'])
plt.title('Boxplot of Number of Rooms by Property Type')
plt.xlabel('Property Type')
plt.ylabel('Number of Rooms')
plt.show()

# %% [markdown]
# # 📊 Scatter plots are commonly used for visualizing two numerical variables

# %% [markdown]
# ### We can use standard *scatterplot* with *property_type* as a *hue* so we can better grasp the relationship between *property_size_sqft* and *price*
# * Try to set *alpha* parameter for opacity settings

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_full, x='property_size_sqft', y='price', hue='property_type')
plt.title('Scatterplot of Property Size vs Price by Property Type')
plt.xlabel('Property Size (sqft)')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# # 📊 Correlation
# * 🔎 What does the *correlation coefficient* tell you?
# * What is the range of it?
# * Is it useful for each type of relationship?
# * 💡 **Correlation is not causation**
#     * e.g. Ice cream sales X Number of thefts
#     * Means that two variables are associated with each other, but it does not imply that one variable causes the other to change.
#
# - Take a look at [this link](https://www.dummies.com/education/math/statistics/how-to-interpret-a-correlation-coefficient-r/)
# - See also [this](https://www.simplypsychology.org/correlation.html) or [this](https://www.investopedia.com/ask/answers/032515/what-does-it-mean-if-correlation-coefficient-positive-negative-or-zero.asp) for some more info about the topic
#
# ![meme03](https://github.com/lowoncuties/VSB-FEI-Machine-Learning-Exercises/blob/main/images/ml_02_meme_03.png?raw=true)

# %% [markdown]
# ## We can compute the correlation matrix using *corr()* function
# * Select columns first
#
# > ['property_size_sqft', 'price', 'constructed_year', 'rooms', 'garage', 'garden', 'crime_cases_reported']

# %%
df_selected = df_full[['property_size_sqft', 'price', 'constructed_year', 'rooms', 'garage', 'garden', 'crime_cases_reported']]

# %% [markdown]
# ### Visualize correlations using Heatmap

# %%
df_corr = df_selected.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(df_corr, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Data Transformations
#
# It is important to select the appropriate scaling method of the number features
# * There are many ways how to do this - **MinMax, StandardScaler, PowerTransform, ...**
# * This step heavily depends on a domain knowledge because the scales of the features have significant effect on a distances between couples of dataset instances
#     - It is clear that if one variable is in range **(0,1)** and the second one is in a range **(5000, 10 000)**, the difference in the **second feature** will be definitely **more important** than in the  first one from the numerical point of view
#     - Although it is possible that from the **domain point of view** the **first variable may be more important**
#     - 💡 Thus it is a good idea to at least transform the features into a **simiiar scales so the effect on the distance value would be similiar**
#     - Transformation depends heavily on the statistical distribution of the feature
#         - 💡You can use PowerTransform for a heavy-tailed distribution, **Standardization or MinMax normalization for normally distributed features** etc.

# %% [markdown]
# ### Create new DataFrame for scaled values

# %%
df_scaled = pd.DataFrame(index = df_full.index)

# %% [markdown]
# ## Take a look at the *price* feature distribution
# * What transformation would be appropriate based on that?

# %%
# print the scalled price
print(df_scaled['price'])
# Out:
# 0        -0.974224
# 1        -1.202955
# 2        -0.570940
# 3        -0.126759
# 4        -1.355320
#             ...
# 199995   -1.228706
# 199996    0.290486
# 199997    0.490228
# 199998   -1.103852
# 199999   -0.586002
# Name: price, Length: 200000, dtype: float64

# %% [markdown]
# ## Plot histogram of the transformed feature
# * 🔎 What has changed?

# %%
df_scaled['price'] = sklearn.preprocessing.scale(df_full['price'])
df_scaled['price'].hist(bins=50)
plt.title('Scaled Price Distribution')
plt.xlabel('Scaled Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Take a look at the *property_size_sqft* feature distribution
# * What transformation would be appropriate based on that?

# %%
df_scaled['property_size_sqft'] = sklearn.preprocessing.scale(df_full['property_size_sqft'])
print(df_scaled['property_size_sqft'])
# Out:
# 0        -1.366521
# 1        -1.209701
# 2         0.592795
# 3         0.321305
# 4        -1.651648
#             ...
# 199995   -1.556192
# 199996    0.385768
# 199997    0.252502
# 199998   -0.923335
# 199999    0.282874
# Name: property_size_sqft, Length: 200000, dtype: float64

# %% [markdown]
# ## Plot histogram of the transformed feature
# * 🔎 What has changed?

# %%
df_scaled['property_size_sqft'].hist(bins=50)
plt.title('Scaled Property Size Distribution')
plt.xlabel('Scaled Property Size (sqft)')
plt.ylabel('Frequency')
plt.show()
